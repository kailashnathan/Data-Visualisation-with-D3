# %%
import pandas as pd

# %%
data=pd.read_csv('MessiRonaldo.csv')

# %%
data
# Out:
#      Goal #        Date        Event type     Match type Home/Away?  Minute  \
# 0       1.0  06-01-2013           La Liga            NaN          h    68.0
# 1       2.0  06-01-2013           La Liga            NaN          h    70.0
# 2       3.0  20-01-2013           La Liga            NaN          a    36.0
# 3       4.0  20-01-2013           La Liga            NaN          a    41.0
# 4       5.0  27-01-2013           La Liga            NaN          h    62.0
# 5       6.0  27-01-2013           La Liga            NaN          h    65.0
# 6       7.0  27-01-2013           La Liga            NaN          h    72.0
# 7       8.0  09-02-2013           La Liga            NaN          h    26.0
# 8       9.0  09-02-2013           La Liga            NaN          h    46.0
# 9      10.0  09-02-2013           La Liga            NaN          h    59.0
# 10     11.0  13-02-2013  Champions League    Round of 16          h    30.0
# ...
